# %% [markdown]
# <a href="https://colab.research.google.com/github/maidyjoshi/PCVK_Ganjil_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]

for url in urls:
          image = io.imread(url)
          image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
          image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
          final_frame = cv.hconcat((image, image_2))
          cv2_imshow(final_frame)
          print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# Pertanyaan:
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# **Jawab: karena praktikum ini dapat dilakukan tanpa konfigurasi dan mengakases GPU secara gratis sekaligus dapat di sinkronasikan atau dihubungkan langsung dengan Github**
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# **Jawab: numpy: membentuk dimensional array, pandas: memadukan libary numpy untuk mengatur dan membentuk data frame, cv2: Untuk menggunakan pengolahan citra, skimage: library pendukung proses dalam gambar pada python, matplotlib: pembuatan visualisasi data seperti membuat plot grafik**
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# **Jawab: Pengaruh pada size gambar dengan memanggil parameter fx dan fy**
#
# 4. Perhatikan potongan kode progam berikut :
# for y in range (lebar):
#   image_3[int((tinggi)/2),y] = [255,255,255]
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
# **Jawab: menambahkan sebuah plot grafik atau garis dengan warna putih RGB [255, 255, 255]**
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
# **Jawab: Resolusi mengacu pada kerapatan pixel dalam sebuah gambar. Semakin besar resolusi gambar, semakin baik kualitasnya. Semakin besar resolusi, tampilan detail gambar akan semakin tampak.**

# %%
#garis vertikal
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
    image_3[x, int(lebar/2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#garis silang
for i in range(tinggi):
    j = (i * lebar) // tinggi
    image_3[i, j] = [255, 255, 255]

for i in range(tinggi):
    j = lebar - (i * lebar) // tinggi - 1
    image_3[i, j] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

kotak_lebar = lebar // 5
kotak_tinggi = tinggi // 100
posisi_x = lebar // 6
posisi_y = tinggi // 2

for y in range(posisi_y, posisi_y + kotak_tinggi):
    for x in range(posisi_x, posisi_x + kotak_lebar):
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# # **TUGAS KELOMPOK 09**

# %%
from google.colab import drive
drive.mount('/content/drive')

img_4 = cv.imread('drive/MyDrive/SEMESTER5/PCVK/ktp.png')
img_5 = cv.cvtColor(img_4, cv.COLOR_BGR2RGB)
cv2_imshow(img_4)
plt.imshow(img_5)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=603x364>

# %%
# NIK
img_4s = np.copy(img_4)
for y in range (180,440):
  for x in range (26,52):
    img_4s[x,y] = [0,0,0]
# Tempat/Tgl Lahir
img_4ss = np.copy(img_4s)
for y in range (150,466):
  for x in range (5,24):
    img_4ss[x,y] = [0,0,225]

final_frame = cv.hconcat((img_4, img_4ss))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1206x364>
